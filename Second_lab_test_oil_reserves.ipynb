# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('oil_reserves.csv')

# %%
data1=data.applymap(lambda x:x.strip() if isinstance(x,str) else x)

# %%
data1.head(5)
# Out:
#                Region Country/ Region     2010     2011     2012     2013  \
# 0       North America              US   34.990   39.775   44.180   48.463
# 1       North America          Canada  174.848  174.177  173.716  173.038
# 2       North America          Mexico   11.691   11.394   11.424   11.079
# 3  S. & Cent. America       Argentina    2.524    2.525    2.354    2.330
# 4  S. & Cent. America          Brazil   14.246   15.050   15.314   15.593
#
#       2014     2015     2016
# 0   54.962   47.987   47.987
# 1  172.156  171.512  171.512
# 2   10.816    7.977    7.977
# 3    2.380    2.395    2.395
# 4   16.184   13.000   12.634

# %%
data1.isnull().sum()
# Out:
# Region             0
# Country/ Region    0
# 2010               1
# 2011               1
# 2012               0
# 2013               0
# 2014               0
# 2015               0
# 2016               0
# dtype: int64

# %%
data1.shape
# Out:
# (54, 9)

# %%
#1.	Which region has max oil reserves from 2014 to 2016?
d1=data1.groupby('Region')['2014','2015','2016'].sum(axis=1)
print(d1.columns)
d1
# Out:
# Index(['2014', '2015', '2016'], dtype='object')
#                        2014     2015     2016
# Region
# Africa              129.221  128.191  127.974
# Asia Pacific         49.280   48.815   48.386
# Europe & Eurasia    154.612  154.892  161.509
# Middle East         803.764  803.048  813.966
# North America       237.934  227.476  227.476
# S. & Cent. America  331.731  329.032  327.959

# %%
d1.sum(axis=1).idxmax(axis=1)
# Out:
# 'Middle East'

# %%
#2.	With suitable visualization show the oil reserves of India from 2010 to 2016.
d2=data1[data1['Country/ Region']=='India']
d2
# Out:
#           Region Country/ Region   2010   2011  2012   2013   2014   2015  \
# 48  Asia Pacific           India  5.833  5.704  5.72  5.711  5.743  4.786
#
#      2016
# 48  4.677

# %%
d3=d2.drop('Region',axis=1)
d4=d3.set_index('Country/ Region')
x=d4.columns
y=d4.iloc[0,:].values
print(x)
print(y)
print(type(y))
print(type(y))
d4
# Out:
# Index(['2010', '2011', '2012', '2013', '2014', '2015', '2016'], dtype='object')
# [5.833 5.704 5.72  5.711 5.743 4.786 4.677]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
#                   2010   2011  2012   2013   2014   2015   2016
# Country/ Region
# India            5.833  5.704  5.72  5.711  5.743  4.786  4.677

# %% [markdown]
# data1.head()

# %%
plt.plot(x,y,linestyle="dotted", marker='o')
#labels
plt.xlabel("Year")
plt.ylabel("Oil Reserves")
plt.title("Oil Reserves in India")

plt.show()

# %%
#3.	List the countries having maximum oil reserves in each region.
data1['total_oil_reserve']=data1.iloc[:,2:9].sum(axis=1)
data1
# Out:
#                 Region              Country/ Region     2010     2011  \
# 0        North America                           US   34.990   39.775
# 1        North America                       Canada  174.848  174.177
# 2        North America                       Mexico   11.691   11.394
# 3   S. & Cent. America                    Argentina    2.524    2.525
# 4   S. & Cent. America                       Brazil   14.246   15.050
# 5   S. & Cent. America                     Colombia    1.900    1.988
# 6   S. & Cent. America                      Ecuador    6.158    7.210
# 7   S. & Cent. America                         Peru    1.240    1.206
# 8   S. & Cent. America            Trinidad & Tobago    0.830    0.830
# 9   S. & Cent. America                    Venezuela  296.501  297.571
# 10  S. & Cent. America     Other S. & Cent. America    0.768    0.507
# 15    7.495    7.047    6.539    8.005    7.601             50.374
# 16    0.600    0.600    0.600    0.600    0.600              4.200
# 17  105.492  105.016  103.164  102.375  109.500            737.056
# 18    0.600    0.600    0.600    0.600    0.600              4.200
# 19    3.037    3.030    2.805    2.542    2.542             19.859
# 20    0.594    0.594    0.594    0.594    0.594              4.158
# 21    2.013    2.008    2.058    2.068    2.091             14.596
# 22  157.300  157.600  157.800  158.400  158.900           1095.750
# 23  140.300  144.211  143.069  142.503  153.000            981.183
# 24  101.500  101.500  101.500  101.500  101.500            710.500
# 25    5.500    4.974    5.151    5.306    5.373             37.304
# 26   25.229   25.063   25.705   25.244   25.244            175.069
# 27  265.850  265.850  267.000  266.578  266.455           1861.654
# 28    2.500    2.500    2.500    2.500    2.500             17.500
# 29   97.800   97.800   97.800   97.800   97.800            684.600
# 30    3.000    3.000    3.000    3.000    3.000             21.000
# 31    0.279    0.261    0.239    0.217    0.194              2.119
# 32   12.200   12.200   12.200   12.200   12.200             85.400
# 33   12.667   12.667   12.598   11.776   11.567             79.830
# 34    1.500    1.500    1.500    1.500    1.500             10.500
# 35    1.600    1.600    1.600    1.600    1.600             11.200
# 36    4.200    3.900    3.681    3.473    3.473             27.527
# 37    1.705    1.705    1.100    1.100    1.100             10.120
# 38    2.000    2.000    2.000    2.000    2.000             14.000
# 39   48.472   48.363   48.363   48.363   48.363            337.035
# 40   37.139   37.070   37.070   37.070   37.062            259.811
# 41    3.500    3.500    3.500    3.500    3.500             17.500
# 42    1.500    1.500    1.500    1.500    1.500             17.500
# 43    0.425    0.425    0.425    0.425    0.425              2.975
# 44    3.684    3.684    3.684    3.684    3.684             22.872
# 45    3.922    3.957    3.982    3.985    3.985             27.535
# 46    1.100    1.100    1.100    1.100    1.100              7.700
# 47   24.409   24.702   25.142   25.655   25.655            172.548
# 48    5.720    5.711    5.743    4.786    4.677             38.174
# 49    3.741    3.693    3.625    3.603    3.307             25.940
# 50    3.668    3.750    3.600    3.600    3.600             25.696
# 51    0.449    0.462    0.405    0.396    0.396              3.003
# 52    4.400    4.400    4.400    4.400    4.400             30.800
# 53    1.075    1.345    1.283    1.290    1.266              8.476

# %%
new1=data1.groupby(['Region'])['total_oil_reserve'].max()
new1.values
new1.index
# Out:
# Index(['Africa', 'Asia Pacific', 'Europe & Eurasia', 'Middle East',
#        'North America', 'S. & Cent. America'],
#       dtype='object', name='Region')

# %%
#4 Draw suitable visualization which shows the share of oil reserves by each region
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = new1.index
sizes = new1.values
#explode = (0, 0, 0, 0)
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
plt.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=135)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
#5.	Find the world’s top 5 countries having maximum oil reserves in the 2015. 
#Show their % of share in total oil reserve for the same year.
new2=data1.sort_values('2015')[['Country/ Region','2015']].tail(5)
new2
# Out:
#    Country/ Region     2015
# 23            Iraq  142.503
# 22            Iran  158.400
# 1           Canada  171.512
# 27    Saudi Arabia  266.578
# 9        Venezuela  300.878

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = new2['Country/ Region']
sizes = new2['2015']
#explode = (0, 0, 0, 0)
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
plt.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=135)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
